# %%
import os
obs_dir = '/home/xilinx/jupyter_notebooks/spectrum-analyzer/comparison/load/LNA/long_load_20250619_211802'
files = sorted(os.listdir(obs_dir))
print(f"Files saved so far: {len(files)}")
for f in files:
    print(f"  {f}")
# Out:
# Files saved so far: 91
#   checkpoint_N00050.npy
#   checkpoint_N00100.npy
#   checkpoint_N00150.npy
#   checkpoint_N00200.npy
#   checkpoint_N00250.npy
#   checkpoint_N00300.npy
#   checkpoint_N00350.npy
#   checkpoint_N00400.npy
#   checkpoint_N00450.npy
#   checkpoint_N00500.npy
#   checkpoint_N00550.npy
#   checkpoint_N00600.npy
#   checkpoint_N00650.npy
#   checkpoint_N00700.npy
#   checkpoint_N00750.npy
#   checkpoint_N00800.npy
#   checkpoint_N00850.npy
#   checkpoint_N00900.npy
#   checkpoint_N00950.npy
#   checkpoint_N01000.npy
#   checkpoint_N01050.npy
#   checkpoint_N01100.npy
#   checkpoint_N01150.npy
#   checkpoint_N01200.npy
#   checkpoint_N01250.npy
#   checkpoint_N01300.npy
#   checkpoint_N01350.npy
#   checkpoint_N01400.npy
#   checkpoint_N01450.npy
#   checkpoint_N01500.npy
#   checkpoint_N01550.npy
#   checkpoint_N01600.npy
#   checkpoint_N01650.npy
#   checkpoint_N01700.npy
#   checkpoint_N01750.npy
#   checkpoint_N01800.npy
#   checkpoint_N01850.npy
# ...
